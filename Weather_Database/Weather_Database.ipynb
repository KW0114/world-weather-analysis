# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the time library and json for printing purposes 
import time
import json

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.)
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description)

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | annau
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | fomboni
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | iracoubo
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | hofn
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | opuwo
# Processing Record 20 of Set 1 | ahipara
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | matay
# Processing Record 23 of Set 1 | katherine
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | tecate
# Processing Record 29 of Set 1 | urumqi
# Processing Record 30 of Set 1 | port hedland
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | santa cruz
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | pangnirtung
# Processing Record 37 of Set 1 | riverton
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | acarau
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | jutai
# Processing Record 42 of Set 1 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 1 | ulvik
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | sinnamary
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | labuhan
# Processing Record 50 of Set 1 | nishihara
# Processing Record 1 of Set 2 | waingapu
# Processing Record 2 of Set 2 | kharp
# Processing Record 3 of Set 2 | tommot
# Processing Record 4 of Set 2 | camapua
# Processing Record 5 of Set 2 | puerto escondido
# Processing Record 6 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 2 | wanaka
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | south lake tahoe
# Processing Record 14 of Set 2 | ouallam
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | road town
# Processing Record 18 of Set 2 | yakeshi
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | macenta
# Processing Record 23 of Set 2 | huarmey
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | general roca
# Processing Record 26 of Set 2 | hanamaki
# Processing Record 27 of Set 2 | gomel
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | mahibadhoo
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | poopo
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 2 | ridgecrest
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | sibu
# Processing Record 41 of Set 2 | yuzhno-kurilsk
# Processing Record 42 of Set 2 | togur
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | guerrero negro
# Processing Record 46 of Set 2 | dong hoi
# Processing Record 47 of Set 2 | canatlan
# Processing Record 48 of Set 2 | pimentel
# Processing Record 49 of Set 2 | biltine
# Processing Record 50 of Set 2 | aripuana
# Processing Record 1 of Set 3 | kamenka
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | northam
# Processing Record 4 of Set 3 | nicoya
# Processing Record 5 of Set 3 | wanning
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | teguldet
# Processing Record 8 of Set 3 | mayo
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | komsomolskiy
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | burnie
# Processing Record 14 of Set 3 | atuona
# Processing Record 15 of Set 3 | krasnoselkup
# Processing Record 16 of Set 3 | grindavik
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | chipinge
# Processing Record 20 of Set 3 | epernay
# Processing Record 21 of Set 3 | dekar
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | podosinovets
# Processing Record 24 of Set 3 | kapit
# Processing Record 25 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | yumen
# Processing Record 32 of Set 3 | zalesovo
# Processing Record 33 of Set 3 | puerto ayora
# Processing Record 34 of Set 3 | natal
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | coari
# Processing Record 37 of Set 3 | takhtamygda
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | vuktyl
# Processing Record 43 of Set 3 | beberibe
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | beringovskiy
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | neuquen
# Processing Record 48 of Set 3 | hamilton
# Processing Record 49 of Set 3 | faya
# Processing Record 50 of Set 3 | verkhoshizhemye
# Processing Record 1 of Set 4 | kahului
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | southbridge
# Processing Record 4 of Set 4 | solnechnyy
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | carahue
# Processing Record 7 of Set 4 | neiafu
# Processing Record 8 of Set 4 | menongue
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | pueblo bello
# Processing Record 11 of Set 4 | saint-georges
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | bereda
# Processing Record 14 of Set 4 | berbera
# Processing Record 15 of Set 4 | vila do maio
# Processing Record 16 of Set 4 | pelaya
# Processing Record 17 of Set 4 | gavrilovka vtoraya
# Processing Record 18 of Set 4 | samatau
# City not found. Skipping...
# Processing Record 19 of Set 4 | padilla
# Processing Record 20 of Set 4 | srednekolymsk
# Processing Record 21 of Set 4 | den helder
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | cape canaveral
# Processing Record 24 of Set 4 | toucheng
# Processing Record 25 of Set 4 | le port
# Processing Record 26 of Set 4 | bijar
# Processing Record 27 of Set 4 | neklyudovo
# Processing Record 28 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 4 | deep river
# Processing Record 30 of Set 4 | hovd
# Processing Record 31 of Set 4 | livny
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | omagh
# Processing Record 34 of Set 4 | mehamn
# Processing Record 35 of Set 4 | auki
# Processing Record 36 of Set 4 | shingu
# Processing Record 37 of Set 4 | deputatskiy
# Processing Record 38 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | mackenzie
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 43 of Set 4 | puerto rico
# Processing Record 44 of Set 4 | roma
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | troitskoye
# Processing Record 47 of Set 4 | araouane
# Processing Record 48 of Set 4 | constantine
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | palmer
# Processing Record 3 of Set 5 | eureka
# Processing Record 4 of Set 5 | aktau
# Processing Record 5 of Set 5 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 6 of Set 5 | ust-maya
# Processing Record 7 of Set 5 | smirnykh
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | pleszew
# Processing Record 10 of Set 5 | barrow
# Processing Record 11 of Set 5 | bubaque
# Processing Record 12 of Set 5 | clyde river
# Processing Record 13 of Set 5 | metro
# Processing Record 14 of Set 5 | marsa matruh
# Processing Record 15 of Set 5 | wum
# Processing Record 16 of Set 5 | minab
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | praia
# Processing Record 22 of Set 5 | augusto correa
# Processing Record 23 of Set 5 | shimoni
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | rabo de peixe
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | lengshuitan
# Processing Record 29 of Set 5 | mareeba
# Processing Record 30 of Set 5 | buala
# Processing Record 31 of Set 5 | matagami
# Processing Record 32 of Set 5 | baiyin
# Processing Record 33 of Set 5 | sampit
# Processing Record 34 of Set 5 | shizunai
# Processing Record 35 of Set 5 | neepawa
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | sakakah
# Processing Record 39 of Set 5 | kungurtug
# Processing Record 40 of Set 5 | chuy
# Processing Record 41 of Set 5 | aswan
# Processing Record 42 of Set 5 | moss vale
# Processing Record 43 of Set 5 | san jeronimo
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | magnolia
# Processing Record 46 of Set 5 | la grande
# Processing Record 47 of Set 5 | byron bay
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | geraldton
# Processing Record 50 of Set 5 | skibbereen
# Processing Record 1 of Set 6 | cabedelo
# Processing Record 2 of Set 6 | chicama
# Processing Record 3 of Set 6 | codrington
# Processing Record 4 of Set 6 | oswego
# Processing Record 5 of Set 6 | kampot
# Processing Record 6 of Set 6 | butaritari
# Processing Record 7 of Set 6 | chapais
# Processing Record 8 of Set 6 | tiruchchendur
# Processing Record 9 of Set 6 | kudahuvadhoo
# Processing Record 10 of Set 6 | maraba
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | fukue
# Processing Record 13 of Set 6 | ruthin
# Processing Record 14 of Set 6 | paamiut
# Processing Record 15 of Set 6 | vilyuysk
# Processing Record 16 of Set 6 | borama
# City not found. Skipping...
# Processing Record 17 of Set 6 | khao wong
# Processing Record 18 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | okhotsk
# Processing Record 21 of Set 6 | kruisfontein
# Processing Record 22 of Set 6 | susangerd
# Processing Record 23 of Set 6 | ulm
# Processing Record 24 of Set 6 | lorengau
# Processing Record 25 of Set 6 | ketchikan
# Processing Record 26 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 6 | at-bashi
# Processing Record 28 of Set 6 | honiara
# Processing Record 29 of Set 6 | rio tercero
# Processing Record 30 of Set 6 | lucapa
# Processing Record 31 of Set 6 | penzance
# Processing Record 32 of Set 6 | visaginas
# Processing Record 33 of Set 6 | ilhabela
# Processing Record 34 of Set 6 | kaitangata
# Processing Record 35 of Set 6 | athabasca
# Processing Record 36 of Set 6 | tiznit
# Processing Record 37 of Set 6 | baghmara
# Processing Record 38 of Set 6 | colac
# Processing Record 39 of Set 6 | makung
# City not found. Skipping...
# Processing Record 40 of Set 6 | ibra
# Processing Record 41 of Set 6 | ulaangom
# Processing Record 42 of Set 6 | kuruman
# Processing Record 43 of Set 6 | porto velho
# Processing Record 44 of Set 6 | sao filipe
# Processing Record 45 of Set 6 | kavaratti
# Processing Record 46 of Set 6 | owando
# Processing Record 47 of Set 6 | baruun-urt
# Processing Record 48 of Set 6 | awbari
# Processing Record 49 of Set 6 | kodiak
# Processing Record 50 of Set 6 | dhidhdhoo
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | qaanaaq
# Processing Record 3 of Set 7 | coihaique
# Processing Record 4 of Set 7 | calimanesti
# Processing Record 5 of Set 7 | duminichi
# Processing Record 6 of Set 7 | ambon
# Processing Record 7 of Set 7 | kysyl-syr
# Processing Record 8 of Set 7 | aykhal
# Processing Record 9 of Set 7 | provideniya
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | la ronge
# Processing Record 12 of Set 7 | bridgeton
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | cap malheureux
# Processing Record 16 of Set 7 | haimen
# Processing Record 17 of Set 7 | ekimchan
# Processing Record 18 of Set 7 | jalu
# Processing Record 19 of Set 7 | mingguang
# Processing Record 20 of Set 7 | norman wells
# Processing Record 21 of Set 7 | san quintin
# Processing Record 22 of Set 7 | gwanda
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | capao da canoa
# Processing Record 25 of Set 7 | rajapur
# Processing Record 26 of Set 7 | aklavik
# Processing Record 27 of Set 7 | bestobe
# Processing Record 28 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 7 | fairbanks
# Processing Record 30 of Set 7 | morris
# Processing Record 31 of Set 7 | inyonga
# Processing Record 32 of Set 7 | victor harbor
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | tecoanapa
# Processing Record 35 of Set 7 | baloda
# Processing Record 36 of Set 7 | price
# Processing Record 37 of Set 7 | inverell
# Processing Record 38 of Set 7 | erenhot
# Processing Record 39 of Set 7 | lamu
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | mahebourg
# Processing Record 42 of Set 7 | beyla
# Processing Record 43 of Set 7 | asau
# Processing Record 44 of Set 7 | nouadhibou
# Processing Record 45 of Set 7 | bombay
# Processing Record 46 of Set 7 | lobau
# Processing Record 47 of Set 7 | nabire
# Processing Record 48 of Set 7 | kachiry
# Processing Record 49 of Set 7 | bredasdorp
# Processing Record 50 of Set 7 | ertil
# Processing Record 1 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 8 | imbituba
# Processing Record 3 of Set 8 | binuangan
# Processing Record 4 of Set 8 | otane
# Processing Record 5 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | vostochnyy
# Processing Record 8 of Set 8 | los llanos de aridane
# Processing Record 9 of Set 8 | montrose
# Processing Record 10 of Set 8 | le vauclin
# Processing Record 11 of Set 8 | vila velha
# Processing Record 12 of Set 8 | san rafael
# Processing Record 13 of Set 8 | trairi
# Processing Record 14 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 8 | mnogovershinnyy
# Processing Record 16 of Set 8 | mitchell
# Processing Record 17 of Set 8 | nome
# Processing Record 18 of Set 8 | nizwa
# Processing Record 19 of Set 8 | huangchuan
# Processing Record 20 of Set 8 | takapau
# Processing Record 21 of Set 8 | havelock
# Processing Record 22 of Set 8 | nanning
# Processing Record 23 of Set 8 | kibondo
# Processing Record 24 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 8 | manokwari
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | kargasok
# Processing Record 30 of Set 8 | saint-francois
# Processing Record 31 of Set 8 | nalut
# Processing Record 32 of Set 8 | kibakwe
# Processing Record 33 of Set 8 | butare
# Processing Record 34 of Set 8 | pedasi
# Processing Record 35 of Set 8 | kenai
# Processing Record 36 of Set 8 | todos santos
# Processing Record 37 of Set 8 | necochea
# Processing Record 38 of Set 8 | yatou
# Processing Record 39 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 8 | malchevskaya
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | san juan de uraba
# Processing Record 43 of Set 8 | zavetnoye
# Processing Record 44 of Set 8 | luis correia
# Processing Record 45 of Set 8 | douglas
# Processing Record 46 of Set 8 | chengdu
# Processing Record 47 of Set 8 | nantucket
# Processing Record 48 of Set 8 | ballina
# Processing Record 49 of Set 8 | nybro
# Processing Record 50 of Set 8 | dawei
# Processing Record 1 of Set 9 | saraiu
# Processing Record 2 of Set 9 | waitati
# Processing Record 3 of Set 9 | felanitx
# Processing Record 4 of Set 9 | kalabo
# Processing Record 5 of Set 9 | harper
# Processing Record 6 of Set 9 | aranos
# Processing Record 7 of Set 9 | fuxin
# Processing Record 8 of Set 9 | jubayl
# City not found. Skipping...
# Processing Record 9 of Set 9 | chitipa
# Processing Record 10 of Set 9 | nezhinka
# Processing Record 11 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | port hawkesbury
# Processing Record 14 of Set 9 | zhuanghe
# Processing Record 15 of Set 9 | ario
# City not found. Skipping...
# Processing Record 16 of Set 9 | beni
# Processing Record 17 of Set 9 | rehoboth
# Processing Record 18 of Set 9 | townsville
# Processing Record 19 of Set 9 | erzin
# Processing Record 20 of Set 9 | tuatapere
# Processing Record 21 of Set 9 | oranjemund
# Processing Record 22 of Set 9 | bokoro
# Processing Record 23 of Set 9 | ginda
# Processing Record 24 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 9 | kamaishi
# Processing Record 26 of Set 9 | tezu
# Processing Record 27 of Set 9 | fairview
# Processing Record 28 of Set 9 | bontang
# Processing Record 29 of Set 9 | jamame
# Processing Record 30 of Set 9 | aden
# Processing Record 31 of Set 9 | fernan-nunez
# Processing Record 32 of Set 9 | dingle
# Processing Record 33 of Set 9 | dalsingh sarai
# Processing Record 34 of Set 9 | kortkeros
# Processing Record 35 of Set 9 | kovdor
# Processing Record 36 of Set 9 | shubarshi
# Processing Record 37 of Set 9 | huron
# Processing Record 38 of Set 9 | namatanai
# Processing Record 39 of Set 9 | krasnoborsk
# Processing Record 40 of Set 9 | ugoofaaru
# Processing Record 41 of Set 9 | maraa
# Processing Record 42 of Set 9 | mehran
# Processing Record 43 of Set 9 | karaton
# Processing Record 44 of Set 9 | cedar city
# Processing Record 45 of Set 9 | verdun
# Processing Record 46 of Set 9 | krasnaya gorka
# Processing Record 47 of Set 9 | pisco
# Processing Record 48 of Set 9 | sompeta
# Processing Record 49 of Set 9 | sorong
# Processing Record 50 of Set 9 | iquitos
# Processing Record 1 of Set 10 | angoche
# Processing Record 2 of Set 10 | caravelas
# Processing Record 3 of Set 10 | gushikawa
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | lardos
# Processing Record 6 of Set 10 | asfi
# Processing Record 7 of Set 10 | oyama
# Processing Record 8 of Set 10 | upata
# Processing Record 9 of Set 10 | trapani
# Processing Record 10 of Set 10 | champerico
# Processing Record 11 of Set 10 | sadiqabad
# Processing Record 12 of Set 10 | thinadhoo
# Processing Record 13 of Set 10 | saint-joseph
# Processing Record 14 of Set 10 | padang
# Processing Record 15 of Set 10 | salalah
# Processing Record 16 of Set 10 | vila
# Processing Record 17 of Set 10 | badarpur
# Processing Record 18 of Set 10 | gao
# Processing Record 19 of Set 10 | pingliang
# Processing Record 20 of Set 10 | souillac
# Processing Record 21 of Set 10 | vyborg
# Processing Record 22 of Set 10 | high level
# Processing Record 23 of Set 10 | healdsburg
# Processing Record 24 of Set 10 | serov
# Processing Record 25 of Set 10 | whitehorse
# Processing Record 26 of Set 10 | muli
# Processing Record 27 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 28 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 10 | milkovo
# Processing Record 30 of Set 10 | ardesen
# Processing Record 31 of Set 10 | naantali
# Processing Record 32 of Set 10 | mus
# Processing Record 33 of Set 10 | ostrovnoy
# Processing Record 34 of Set 10 | goderich
# Processing Record 35 of Set 10 | beira
# Processing Record 36 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 10 | lebedinyy
# Processing Record 38 of Set 10 | flinders
# Processing Record 39 of Set 10 | port-gentil
# Processing Record 40 of Set 10 | ankara
# Processing Record 41 of Set 10 | fort nelson
# Processing Record 42 of Set 10 | lantawan
# Processing Record 43 of Set 10 | noumea
# Processing Record 44 of Set 10 | tarauaca
# Processing Record 45 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | purace
# City not found. Skipping...
# Processing Record 47 of Set 10 | ancud
# Processing Record 48 of Set 10 | itaituba
# Processing Record 49 of Set 10 | isangel
# Processing Record 50 of Set 10 | lemon tree passage
# Processing Record 1 of Set 11 | christchurch
# Processing Record 2 of Set 11 | hami
# Processing Record 3 of Set 11 | baykit
# Processing Record 4 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 11 | kuching
# Processing Record 6 of Set 11 | ibanda
# Processing Record 7 of Set 11 | ambilobe
# Processing Record 8 of Set 11 | bloemfontein
# Processing Record 9 of Set 11 | puerto carreno
# Processing Record 10 of Set 11 | gangtok
# Processing Record 11 of Set 11 | alta floresta
# Processing Record 12 of Set 11 | bushenyi
# Processing Record 13 of Set 11 | banjar
# Processing Record 14 of Set 11 | narasannapeta
# Processing Record 15 of Set 11 | sabang
# Processing Record 16 of Set 11 | svetlyy
# Processing Record 17 of Set 11 | makueni
# Processing Record 18 of Set 11 | ampanihy
# Processing Record 19 of Set 11 | birao
# Processing Record 20 of Set 11 | rocha
# Processing Record 21 of Set 11 | cortez
# Processing Record 22 of Set 11 | rudbar
# Processing Record 23 of Set 11 | salta
# Processing Record 24 of Set 11 | gazanjyk
# Processing Record 25 of Set 11 | batemans bay
# Processing Record 26 of Set 11 | sarab
# Processing Record 27 of Set 11 | poum
# Processing Record 28 of Set 11 | shimoda
# Processing Record 29 of Set 11 | labuan
# Processing Record 30 of Set 11 | evensk
# Processing Record 31 of Set 11 | kirkwall
# Processing Record 32 of Set 11 | heerenveen
# Processing Record 33 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | norfolk
# Processing Record 35 of Set 11 | san luis
# Processing Record 36 of Set 11 | sambava
# Processing Record 37 of Set 11 | priargunsk
# Processing Record 38 of Set 11 | waycross
# Processing Record 39 of Set 11 | udachnyy
# Processing Record 40 of Set 11 | omboue
# Processing Record 41 of Set 11 | pogar
# Processing Record 42 of Set 11 | tateyama
# Processing Record 43 of Set 11 | shitkino
# Processing Record 44 of Set 11 | port hardy
# Processing Record 45 of Set 11 | komagane
# Processing Record 46 of Set 11 | balikpapan
# Processing Record 47 of Set 11 | mocuba
# Processing Record 48 of Set 11 | woodward
# Processing Record 49 of Set 11 | vega de alatorre
# Processing Record 50 of Set 11 | kawalu
# Processing Record 1 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 12 | pegnitz
# Processing Record 3 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 4 of Set 12 | piterka
# Processing Record 5 of Set 12 | leh
# Processing Record 6 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 12 | sabha
# Processing Record 8 of Set 12 | zanjan
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | kaniama
# Processing Record 11 of Set 12 | uvalde
# Processing Record 12 of Set 12 | galich
# Processing Record 13 of Set 12 | mantua
# Processing Record 14 of Set 12 | maragogi
# Processing Record 15 of Set 12 | niquero
# Processing Record 16 of Set 12 | pointe michel
# Processing Record 17 of Set 12 | ribeira brava
# Processing Record 18 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 19 of Set 12 | sola
# Processing Record 20 of Set 12 | tivaouane
# Processing Record 21 of Set 12 | gongzhuling
# Processing Record 22 of Set 12 | ardahan
# Processing Record 23 of Set 12 | auriflama
# Processing Record 24 of Set 12 | sobolevo
# Processing Record 25 of Set 12 | muroto
# Processing Record 26 of Set 12 | palauig
# Processing Record 27 of Set 12 | keokuk
# Processing Record 28 of Set 12 | princeton
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | rabak
# Processing Record 31 of Set 12 | graaff-reinet
# Processing Record 32 of Set 12 | toguchin
# Processing Record 33 of Set 12 | itarema
# Processing Record 34 of Set 12 | tamandare
# Processing Record 35 of Set 12 | nanortalik
# Processing Record 36 of Set 12 | bangkok
# Processing Record 37 of Set 12 | surskoye
# Processing Record 38 of Set 12 | chimore
# Processing Record 39 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 40 of Set 12 | katobu
# Processing Record 41 of Set 12 | kailua
# Processing Record 42 of Set 12 | inuvik
# Processing Record 43 of Set 12 | qaqortoq
# Processing Record 44 of Set 12 | bandarbeyla
# Processing Record 45 of Set 12 | banda aceh
# Processing Record 46 of Set 12 | plymouth
# Processing Record 47 of Set 12 | atar
# Processing Record 48 of Set 12 | uddiawan
# Processing Record 49 of Set 12 | lushunkou
# City not found. Skipping...
# Processing Record 50 of Set 12 | soe
# Processing Record 1 of Set 13 | dzilam gonzalez
# Processing Record 2 of Set 13 | winston-salem
# Processing Record 3 of Set 13 | rehli
# Processing Record 4 of Set 13 | polson
# Processing Record 5 of Set 13 | grand gaube
# Processing Record 6 of Set 13 | batsfjord
# Processing Record 7 of Set 13 | shache
# Processing Record 8 of Set 13 | keetmanshoop
# Processing Record 9 of Set 13 | saint-martin-de-crau
# Processing Record 10 of Set 13 | comodoro rivadavia
# Processing Record 11 of Set 13 | fonte boa
# Processing Record 12 of Set 13 | karratha
# Processing Record 13 of Set 13 | anito
# Processing Record 14 of Set 13 | baghdad
# Processing Record 15 of Set 13 | pangai
# Processing Record 16 of Set 13 | hasaki
# Processing Record 17 of Set 13 | pombia
# Processing Record 18 of Set 13 | porbandar
# Processing Record 19 of Set 13 | astana
# Processing Record 20 of Set 13 | hue
# Processing Record 21 of Set 13 | sal rei
# Processing Record 22 of Set 13 | ous
# Processing Record 23 of Set 13 | pindi bhattian
# Processing Record 24 of Set 13 | ulladulla
# Processing Record 25 of Set 13 | rajula
# Processing Record 26 of Set 13 | naze
# Processing Record 27 of Set 13 | gympie
# Processing Record 28 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 13 | cheyenne
# Processing Record 30 of Set 13 | xiongshi
# City not found. Skipping...
# Processing Record 31 of Set 13 | pacific grove
# Processing Record 32 of Set 13 | tilichiki
# Processing Record 33 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 13 | mount gambier
# Processing Record 35 of Set 13 | marienburg
# Processing Record 36 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 13 | lasa
# Processing Record 38 of Set 13 | anadyr
# Processing Record 39 of Set 13 | tripoli
# Processing Record 40 of Set 13 | ust-nera
# Processing Record 41 of Set 13 | rawson
# Processing Record 42 of Set 13 | rio grande city
# Processing Record 43 of Set 13 | leshukonskoye
# Processing Record 44 of Set 13 | coahuayana
# Processing Record 45 of Set 13 | cabatuan
# Processing Record 46 of Set 13 | pokoynoye
# Processing Record 47 of Set 13 | katsuura
# Processing Record 48 of Set 13 | reading
# Processing Record 49 of Set 13 | hualmay
# Processing Record 50 of Set 13 | boffa
# Processing Record 1 of Set 14 | vezirkopru
# Processing Record 2 of Set 14 | dibaya
# City not found. Skipping...
# Processing Record 3 of Set 14 | upington
# Processing Record 4 of Set 14 | port macquarie
# Processing Record 5 of Set 14 | urengoy
# Processing Record 6 of Set 14 | kirkuk
# Processing Record 7 of Set 14 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 8 of Set 14 | mecca
# Processing Record 9 of Set 14 | novaya ladoga
# Processing Record 10 of Set 14 | vostok
# Processing Record 11 of Set 14 | maliq
# Processing Record 12 of Set 14 | orlik
# Processing Record 13 of Set 14 | berberati
# Processing Record 14 of Set 14 | katghora
# Processing Record 15 of Set 14 | barra do corda
# Processing Record 16 of Set 14 | windhoek
# Processing Record 17 of Set 14 | steamboat springs
# Processing Record 18 of Set 14 | morros
# Processing Record 19 of Set 14 | sistranda
# Processing Record 20 of Set 14 | rodrigues alves
# Processing Record 21 of Set 14 | dunedin
# Processing Record 22 of Set 14 | chara
# Processing Record 23 of Set 14 | watsa
# Processing Record 24 of Set 14 | usinsk
# Processing Record 25 of Set 14 | verkhnevilyuysk
# Processing Record 26 of Set 14 | banepa
# Processing Record 27 of Set 14 | sijunjung
# Processing Record 28 of Set 14 | gundorovskiy
# Processing Record 29 of Set 14 | tchibanga
# Processing Record 30 of Set 14 | qasigiannguit
# Processing Record 31 of Set 14 | moroni
# Processing Record 32 of Set 14 | jalgaon
# Processing Record 33 of Set 14 | ende
# Processing Record 34 of Set 14 | henties bay
# Processing Record 35 of Set 14 | harwich
# Processing Record 36 of Set 14 | avera
# Processing Record 37 of Set 14 | silifke
# Processing Record 38 of Set 14 | ji-parana
# City not found. Skipping...
# Processing Record 39 of Set 14 | khasan
# Processing Record 40 of Set 14 | vanavara
# Processing Record 41 of Set 14 | camamu
# Processing Record 42 of Set 14 | kankon
# Processing Record 43 of Set 14 | gusev
# Processing Record 44 of Set 14 | barabai
# Processing Record 45 of Set 14 | seoul
# Processing Record 46 of Set 14 | ulaanbaatar
# Processing Record 47 of Set 14 | egvekinot
# Processing Record 48 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 14 | balkanabat
# Processing Record 50 of Set 14 | barbacena
# Processing Record 1 of Set 15 | mbandaka
# Processing Record 2 of Set 15 | tambacounda
# Processing Record 3 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 15 | kitimat
# Processing Record 6 of Set 15 | corowa
# Processing Record 7 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 8 of Set 15 | pinjaur
# Processing Record 9 of Set 15 | qeshm
# Processing Record 10 of Set 15 | marzuq
# Processing Record 11 of Set 15 | alice town
# Processing Record 12 of Set 15 | boa vista
# Processing Record 13 of Set 15 | vitim
# Processing Record 14 of Set 15 | lerwick
# Processing Record 15 of Set 15 | donghai
# Processing Record 16 of Set 15 | pozo colorado
# Processing Record 17 of Set 15 | nemuro
# Processing Record 18 of Set 15 | luan
# Processing Record 19 of Set 15 | axim
# Processing Record 20 of Set 15 | zilair
# Processing Record 21 of Set 15 | shaunavon
# Processing Record 22 of Set 15 | kalmunai
# Processing Record 23 of Set 15 | sur
# Processing Record 24 of Set 15 | dabat
# Processing Record 25 of Set 15 | vila franca do campo
# Processing Record 26 of Set 15 | korla
# Processing Record 27 of Set 15 | urusha
# Processing Record 28 of Set 15 | acapulco
# Processing Record 29 of Set 15 | walvis bay
# Processing Record 30 of Set 15 | buchanan
# Processing Record 31 of Set 15 | xian
# Processing Record 32 of Set 15 | negombo
# Processing Record 33 of Set 15 | xichang
# Processing Record 34 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 15 | portland
# Processing Record 36 of Set 15 | bougouni
# Processing Record 37 of Set 15 | luoyang
# Processing Record 38 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 39 of Set 15 | college
# Processing Record 40 of Set 15 | rio gallegos
# Processing Record 41 of Set 15 | san carlos de bariloche
# Processing Record 42 of Set 15 | guarumal
# Processing Record 43 of Set 15 | khorixas
# Processing Record 44 of Set 15 | pyay
# Processing Record 45 of Set 15 | bemidji
# Processing Record 46 of Set 15 | half moon bay
# Processing Record 47 of Set 15 | ostersund
# Processing Record 48 of Set 15 | mitsamiouli
# Processing Record 49 of Set 15 | saint marys
# Processing Record 50 of Set 15 | albury
# Processing Record 1 of Set 16 | santa rosa
# Processing Record 2 of Set 16 | taywarah
# Processing Record 3 of Set 16 | quixada
# Processing Record 4 of Set 16 | kawana waters
# City not found. Skipping...
# Processing Record 5 of Set 16 | igarka
# Processing Record 6 of Set 16 | watertown
# Processing Record 7 of Set 16 | pangody
# Processing Record 8 of Set 16 | santa maria
# Processing Record 9 of Set 16 | tenenkou
# Processing Record 10 of Set 16 | grand-santi
# Processing Record 11 of Set 16 | mundo nuevo
# Processing Record 12 of Set 16 | yulara
# Processing Record 13 of Set 16 | atlantis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Rearrange columns
cols = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[cols]

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv('WeatherPy_Database.csv', index_label="City_ID")
